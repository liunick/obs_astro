# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math, sys

# %%
# CONSTANTS #
BASE = 'https://api.astrocats.space/'
B_CONDITIONAL = '/photometry/time+magnitude+e_magnitude+band?format=csv&band=B'
V_CONDITIONAL = '/photometry/time+magnitude+e_magnitude+band?format=csv&band=V'
I_CONDITIONAL = '/photometry/time+magnitude+e_magnitude+band?format=csv&band=I'
BAND_CONDITIONALS = [B_CONDITIONAL, V_CONDITIONAL, I_CONDITIONAL]

B_BAND = 0
V_BAND = 1
I_BAND = 2
BANDS = [B_BAND, V_BAND, I_BAND]
BAND_LABELS = ["B", "V", "I"]

B_BAND_ERROR_MARGIN = 0.8
V_BAND_ERROR_MARGIN = 0.6
I_BAND_ERROR_MARGIN = 0.5
BAND_ERROR_MARGINS = [B_BAND_ERROR_MARGIN, V_BAND_ERROR_MARGIN, I_BAND_ERROR_MARGIN]

INTERPOLATION_CONSTANT = 5
CONTINUITY_CONSTANT = 20
PHILLIPS_DELTA = 15

B_BAND_A = -21.726
B_BAND_B = 2.698
V_BAND_A = -20.883
V_BAND_B = 1.949
I_BAND_A = -19.591
I_BAND_B = 1.076

# %% [markdown]
# # Data PreProcessing
# The data we used was pulled from the [Open Supernova Catalog](https://github.com/astrocatalogs/OACAPI). Using their API, we were able to bulk download all rows of data they had into a CSV, including luminosity distance.

# %%
DATA = pd.read_csv('https://api.astrocats.space/catalog/lumdist+claimedtype?claimedtype=Ia-(.*)&format=csv', error_bad_lines=False)

# %%
DATA.head()
# Out:
#          event   lumdist        claimedtype
# 0  ASASSN-14ar  103.4800            Ia-91bg
# 1  ASASSN-14ba  148.1620      Ia Pec,Ia-91T
# 2  ASASSN-14bd   96.2764         Ia,Ia-91bg
# 3  ASASSN-14eu  102.3000  Ia Pec,Ia,Ia-00cx
# 4  ASASSN-14lq  118.2220          Ia,Ia-91T

# %%
DATA.shape
# Out:
# (471, 3)

# %% [markdown]
# A quick view of our data here exhibits how the data is specifically formated, where each row of data containing the _supernova event name_, the _luminosity distance_, and the _claimed type_ for this event. The API itself was able to give us information on 471 different supernova events, meaning that we would be replicating the analysis done in the paper (WIP) with a lot more data. We plan to use this fact to our advantage, and hopefully reach new conclusions based on our work in this project.

# %% [markdown]
# Before we begin our analysis, it would be useful to do a small amount of exploratory analysis. Our the most important data points are luminosity distance, but at this point we have no insight into the statistical details of it.

# %%
plt.boxplot(DATA['lumdist'].tolist())
# type(DATA['lumdist'].tolist())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x117a5fa90>,
#   <matplotlib.lines.Line2D at 0x117a5fdd8>],
#  'caps': [<matplotlib.lines.Line2D at 0x117a5feb8>,
#   <matplotlib.lines.Line2D at 0x117a684a8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x117a5f710>],
#  'medians': [<matplotlib.lines.Line2D at 0x117a687f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x117a68b38>],
#  'means': []}

# %%
def calc_absolute_magnitude(lumdist, app_mag):
    return app_mag - (5 * (math.log10(lumdist*1000000) - 1))

# %%
def calc_apparent_magnitude(lumdist, abs_mag):
    return abs_mag + (5 * (math.log10(lumdist*1000000) - 1))

# %%
def within_margin(margin, actual, expected):
    return actual < expected + margin and actual > expected - margin

# %%
def calc_phillips_expected_mag(lumdist, band_mag_15, band_type):
    """
    Calculate expected b-band peak absolute magnitude BASEd on the band's magnitude after 15 days
    using the Phillips relationship

    band_mag_15 -- the band's magnitude 15 days after the peak 
    """
    expected_mag = 0
    if band_type == B_BAND:
        expected_mag = B_BAND_A + B_BAND_B * band_mag_15
        
    elif band_type == V_BAND:
        expected_mag = V_BAND_A + V_BAND_B * band_mag_15
    elif band_type == I_BAND:
        expected_mag = I_BAND_A + I_BAND_B * band_mag_15
    return calc_apparent_magnitude(lumdist, expected_mag)

# %%
def interpolate(date1, mag1, date2, mag2, date15):
    """
    Calculate interpolated magnitude for 15 days after peak

    date1   -- date of first mag reading
    mag1    -- value of first mag reading
    date2   -- date of second mag reading
    mag2    -- value of second mag reading
    date15  -- exact date of 15 days after peak

    Returns magnitude at 15 day mark
    """
    slope = (mag2 - mag1) / (date2 - date1)
    days_to_15 = date15 - date1
    mag_delta = slope * days_to_15
    return mag1 + mag_delta

# %%
def check_criteria(sn, sn_data, band_type, f):

    """
    Checks whether a certain supernova fits the time and margin criteria for a specific
    band magnitude

    sn          -- [name, lumdist] of the supernova event
    sn_data     -- Magnitudes of the supernova
    band_type   -- Band type that correspondes to the sought after band magnitude

    Returns an array of booleans: [time_criteria, margin_criteria]
    """

    criteria = [False, False]
    if not sn_data["magnitude"].empty:
        neg_delta_time_tracker = [-float("inf"), None]
        pos_delta_time_tracker = [float("inf"), None]
        
        # Find time at highest magnitude
        peak_mag = sn_data["magnitude"].min()
        peak_index = sn_data["magnitude"].idxmin()
        peak_time = np.floor(sn_data.at[peak_index, 'time'])
        curr_time = peak_time

        # Check for 1 reading every 2 days and for 20 days of readings after peak
        for reading in sn_data[["time", "magnitude"]].values:
            if reading[0] < peak_time:
                continue
            elif reading[0] - INTERPOLATION_CONSTANT > curr_time:
                break
            elif reading[0] > peak_time + CONTINUITY_CONSTANT:
                criteria[0] = True
                break
            curr_time = reading[0]
            
            #check for closest to PHILLIPS_DELTA value
            curr_delta = peak_time - (reading[0] - PHILLIPS_DELTA)
            neg_delta = (peak_time - (neg_delta_time_tracker[0] - PHILLIPS_DELTA))
            pos_delta = (peak_time - (pos_delta_time_tracker[0] - PHILLIPS_DELTA))
            if curr_delta > 0 and curr_delta < neg_delta: 
                neg_delta_time_tracker = [reading[0], reading[1]]
            elif curr_delta < 0 and curr_delta > pos_delta:
                pos_delta_time_tracker = [reading[0], reading[1]]

        #linearly interpolate between 2 points to reach mag15
        if (
            neg_delta_time_tracker[0] is not None and
            neg_delta_time_tracker[1] is not None and
            pos_delta_time_tracker[0] is not None and
            pos_delta_time_tracker[1] is not None
        ):
            mag15 = interpolate(neg_delta_time_tracker[0], neg_delta_time_tracker[1], pos_delta_time_tracker[0], pos_delta_time_tracker[1], peak_time + PHILLIPS_DELTA)
            expected_mag = calc_phillips_expected_mag(sn[1], mag15 - peak_mag, band_type)
            criteria[1] = within_margin(BAND_ERROR_MARGINS[band_type], peak_mag, expected_mag)
            print("Currently observing: " + str(sn[0]))
            print("\tInterpolated mag: " + str(mag15))
            print("\tPeak mag: " + str(peak_mag))
            print("\tLumdist: " + str(sn[1]))
            print("\tExpected mag: " + str(expected_mag))
            sys.stdout.flush()

            f.write(str(sn[0]))
            f.write("\tInterpolated mag: " + str(mag15))
            f.write("\tPeak mag: " + str(peak_mag))
            f.write("\tLumdist: " + str(sn[1]))
            f.write("\tExpected mag: " + str(expected_mag) + "\n")
            
    return criteria

# %%
def run():
    """
    Finds the list of supernova names and iterate through all sought after band magnitudes. Calculates the percentage of supernova that pass criteria set by Phillips' paper.
    """
    b_criteria_sne = []
    v_criteria_sne = []
    i_criteria_sne = []
    
    f = open("output.txt", "w+")

    for sn in DATA[["event", "lumdist"]].values:
        for band in BANDS:
            #Get data - convert columns to numerical values
            sn_data = pd.read_csv(BASE + sn[0] + BAND_CONDITIONALS[band])
            sn_data['magnitude'] = pd.to_numeric(sn_data['magnitude'])
            time_criteria, margin_criteria = check_criteria(sn, sn_data, band, f)

            #All evaluated supernovae satisfy criteria #1
            if time_criteria:
                if band == B_BAND:
                    b_criteria_sne.append([sn[0], margin_criteria])
                elif band == V_BAND:
                    v_criteria_sne.append([sn[0], margin_criteria])
                elif band == I_BAND:
                    i_criteria_sne.append([sn[0], margin_criteria])

    f.close()
    
    criteria_sne = [b_criteria_sne, v_criteria_sne, i_criteria_sne]
    for band in BANDS:
        within_margin_ratio = 0
        # print("List of SNe that satisfy light curves")
        for sn in criteria_sne[band]:
            if sn[1]:
                within_margin_ratio += 1
        total_number_of_sne = len(criteria_sne[band])
        print("--------------------------------------------------------")    
        print("Total SNe that satisfy light curve requirements for " + BAND_LABELS[band] + "-band: " + str(total_number_of_sne))
        print("Percentage of SNe that satisfy" + BAND_LABELS[band] + "-band error on expected peak mag: " + str(within_margin_ratio/total_number_of_sne))

# %%
run()
# Out:
# Currently observing: ASASSN-15fa
# 	Interpolated mag: 17.82657860691475
# 	Peak mag: 16.4723
# 	Lumdist: 123.82600000000001
# 	Expected mag: 17.391902901281192
# Currently observing: ASASSN-15fa
# 	Interpolated mag: 16.915229422267334
# 	Peak mag: 15.9414
# 	Lumdist: 123.82600000000001
# 	Expected mag: 16.47905276382423
# Currently observing: LSQ12gdj
# 	Interpolated mag: 16.530757180156527
# 	Peak mag: 15.945
# 	Lumdist: 140.0
# 	Expected mag: 15.585013050453501
# Currently observing: LSQ12gdj
# 	Interpolated mag: 16.71307013541299
# 	Peak mag: 15.95
# 	Lumdist: 140.0
# 	Expected mag: 16.334863872311114
# Currently observing: LSQ12gdj
# 	Interpolated mag: 17.2330000000001
# 	Peak mag: 16.55
# 	Lumdist: 140.0
# 	Expected mag: 16.874548178391297
# Currently observing: OGLE-2012-SN-040
# 	Interpolated mag: 16.47973374897308
# 	Peak mag: 15.948
# 	Lumdist: 65.742
# 	Expected mag: 15.070360074058378
# Currently observing: OGLE-2014-SN-024
# 	Interpolated mag: 20.282506021586947
# 	Peak mag: 19.689
# 	Lumdist: 480.0
# 	Expected mag: 19.45381866610549
# Currently observing: OGLE-2014-SN-107
# 	Interpolated mag: 18.53356246567758
# 	Peak mag: 18.115
# 	Lumdist: 311.0
# 	Expected mag: 18.32317515820327
# Currently observing: SN1986G
# 	Interpolated mag: 14.086623376623903
# 	Peak mag: 12.41
# 	Lumdist: 2.8
# 	Expected mag: 10.03332002684239
# Currently observing: SN1991T
# 	Interpolated mag: 12.473873873873941
# 	Peak mag: 11.66
# 	Lumdist: 12.6
# 	Expected mag: 10.971684437299707
# Currently observing: SN1991T
# 	Interpolated mag: 12.00832876712331
# 	Peak mag: 11.44
# 	Lumdist: 12.6
# 	Expected mag: 10.726525492711144
# Currently observing: SN1991T
# 	Interpolated mag: 12.051805825242724
# 	Peak mag: 11.62
# 	Lumdist: 12.6
# 	Expected mag: 11.375475793548983
# Currently observing: SN1995al
# 	Interpolated mag: 14.291666666666666
# 	Peak mag: 13.36
# 	Lumdist: 27.0
# 	Expected mag: 12.9444554874616
# Currently observing: SN1995al
# 	Interpolated mag: 13.542857142857068
# 	Peak mag: 12.7
# 	Lumdist: 27.0
# 	Expected mag: 12.916547392223361
# Currently observing: SN1995al
# 	Interpolated mag: 13.895789473684198
# 	Peak mag: 13.53
# 	Lumdist: 27.0
# 	Expected mag: 12.959408294479129
# Currently observing: SN1995bd
# 	Interpolated mag: 18.30561983471075
# 	Peak mag: 17.29
# 	Lumdist: 55.0
# 	Expected mag: 14.715955761520831
# Currently observing: SN1995bd
# 	Interpolated mag: 17.184132231404963
# 	Peak mag: 16.49
# 	Lumdist: 55.0
# 	Expected mag: 14.171677166479501
# Currently observing: SN1996bo
# 	Interpolated mag: 17.546086956521
# 	Peak mag: 16.15
# 	Lumdist: 57.0
# 	Expected mag: 15.820016887056113
# Currently observing: SN1996bo
# 	Interpolated mag: 16.43095238095223
# 	Peak mag: 15.75
# 	Lumdist: 57.0
# 	Expected mag: 14.223550468838354
# Currently observing: SN1996bo
# 	Interpolated mag: 16.189666666666596
# 	Peak mag: 15.67
# 	Lumdist: 57.0
# 	Expected mag: 14.74753561169571
# Currently observing: SN1997cn
# 	Interpolated mag: 19.314230769230754
# 	Peak mag: 17.46
# 	Lumdist: 72.0
# 	Expected mag: 17.56337709754091
# Currently observing: SN1997cn
# 	Interpolated mag: 18.056651376146796
# 	Peak mag: 16.62
# 	Lumdist: 72.0
# 	Expected mag: 16.20369601426644
# Currently observing: SN1997cn
# 	Interpolated mag: 17.200784313725517
# 	Peak mag: 16.4
# 	Lumdist: 72.0
# 	Expected mag: 15.557306403724994
# Currently observing: SN1998ab
# 	Interpolated mag: 17.998977412731044
# 	Peak mag: 16.384
# 	Lumdist: 90.0
# 	Expected mag: 17.402421606744984
# Currently observing: SN1998ab
# 	Interpolated mag: 17.027252566735132
# 	Peak mag: 16.215999999999998
# 	Lumdist: 90.0
# 	Expected mag: 15.469343799763404
# Currently observing: SN1999da
# 	Interpolated mag: 16.606893939393963
# 	Peak mag: 15.949
# 	Lumdist: 54.0
# 	Expected mag: 14.77886267790274
# Currently observing: SN2001V
# 	Interpolated mag: 15.399380149628723
# 	Peak mag: 14.4
# 	Lumdist: 59.0
# 	Expected mag: 15.338593099211224
# Currently observing: SN2001ay
# 	Interpolated mag: 17.653613483939434
# 	Peak mag: 16.719
# 	Lumdist: 137.0
# 	Expected mag: 16.47919001545063
# Currently observing: SN2001ay
# 	Interpolated mag: 16.96349116918732
# 	Peak mag: 16.591
# 	Lumdist: 137.0
# 	Expected mag: 15.526588124528129
# Currently observing: SN2001bg
# 	Interpolated mag: 15.189518703241811
# 	Peak mag: 14.181
# 	Lumdist: 21.0
# 	Expected mag: 12.606079935016005
# Currently observing: SN2001bg
# 	Interpolated mag: 14.515090909090848
# 	Peak mag: 13.8
# 	Lumdist: 21.0
# 	Expected mag: 12.121808655487659
# Currently observing: SN2001bg
# 	Interpolated mag: 14.839818181818174
# 	Peak mag: 14.171
# 	Lumdist: 21.0
# 	Expected mag: 12.739744837305953
# Currently observing: SN2001br
# 	Interpolated mag: 17.71841353383437
# 	Peak mag: 16.476
# 	Lumdist: 92.7279
# 	Expected mag: 16.46208383662609
# Currently observing: SN2001br
# 	Interpolated mag: 17.12927272727254
# 	Peak mag: 16.339
# 	Lumdist: 92.7279
# 	Expected mag: 15.493293667795143
# Currently observing: SN2001br
# 	Interpolated mag: 17.006030075188082
# 	Peak mag: 16.36
# 	Lumdist: 92.7279
# 	Expected mag: 15.940180483243335
# Currently observing: SN2001eh
# 	Interpolated mag: 17.383174496644273
# 	Peak mag: 16.821
# 	Lumdist: 160.0
# 	Expected mag: 15.81134670522587
# Currently observing: SN2001eh
# 	Interpolated mag: 17.253147208121856
# 	Peak mag: 16.757
# 	Lumdist: 160.0
# 	Expected mag: 16.10459082190912
# Currently observing: SN2001eh
# 	Interpolated mag: 17.510439597315248
# 	Peak mag: 16.992
# 	Lumdist: 160.0
# 	Expected mag: 16.98744091999083
# Currently observing: SN2001en
# 	Interpolated mag: 16.526656410256514
# 	Peak mag: 15.237
# 	Lumdist: 64.0
# 	Expected mag: 15.784392864791513
# Currently observing: SN2001en
# 	Interpolated mag: 15.871066666666707
# 	Peak mag: 15.198
# 	Lumdist: 64.0
# 	Expected mag: 14.45970680325285
# Currently observing: SN2001en
# 	Interpolated mag: 16.119409599320424
# 	Peak mag: 15.392
# 	Lumdist: 64.0
# 	Expected mag: 15.222592598788214
# Currently observing: SN2002bf
# 	Interpolated mag: 18.097384580980858
# 	Peak mag: 16.492
# 	Lumdist: 98.0
# 	Expected mag: 17.561457977948827
# Currently observing: SN2002bf
# 	Interpolated mag: 17.075197444844743
# 	Peak mag: 16.589000000000002
# 	Lumdist: 98.0
# 	Expected mag: 15.888278829115414
# Currently observing: SN2002bo
# 	Interpolated mag: 15.422251924671299
# 	Peak mag: 14.024
# 	Lumdist: 22.4
# 	Expected mag: 13.797723784433984
# Currently observing: SN2002bo
# 	Interpolated mag: 14.3224203681055
# 	Peak mag: 13.605
# 	Lumdist: 22.4
# 	Expected mag: 12.266492389108436
# Currently observing: SN2002bo
# 	Interpolated mag: 13.999879396985163
# 	Peak mag: 13.54
# 	Lumdist: 22.4
# 	Expected mag: 12.655070322826852
# Currently observing: SN2002cu
# 	Interpolated mag: 17.742041666666843
# 	Peak mag: 16.356
# 	Lumdist: 105.053
# 	Expected mag: 17.12058271203061
# Currently observing: SN2002cu
# 	Interpolated mag: 16.96347916666675
# 	Peak mag: 16.273
# 	Lumdist: 105.053
# 	Expected mag: 15.569786191196968
# Currently observing: SN2002cu
# 	Interpolated mag: 17.150402985074656
# 	Peak mag: 16.452
# 	Lumdist: 105.053
# 	Expected mag: 16.267523907303797
# Currently observing: SN2002cx
# 	Interpolated mag: 18.320416666666524
# 	Peak mag: 17.45
# 	Lumdist: 165.0
# 	Expected mag: 16.900861804402595
# Currently observing: SN2002cx
# 	Interpolated mag: 17.495000000000342
# 	Peak mag: 17.3
# 	Lumdist: 165.0
# 	Expected mag: 16.706239721069903
# Currently observing: SN2002dj
# 	Interpolated mag: 15.449060200668654
# 	Peak mag: 14.304
# 	Lumdist: 37.0
# 	Expected mag: 14.204381041739005
# Currently observing: SN2002dj
# 	Interpolated mag: 14.811567164179092
# 	Peak mag: 14.128
# 	Lumdist: 37.0
# 	Expected mag: 13.290281023320027
# Currently observing: SN2002dj
# 	Interpolated mag: 14.999700000000164
# 	Peak mag: 14.337
# 	Lumdist: 37.0
# 	Expected mag: 13.96307382033515
# Currently observing: SN2002dl
# 	Interpolated mag: 17.865666666666908
# 	Peak mag: 16.112
# 	Lumdist: 57.0
# 	Expected mag: 16.784766945029777
# Currently observing: SN2002dl
# 	Interpolated mag: 16.956868421052835
# 	Peak mag: 15.949
# 	Lumdist: 57.0
# 	Expected mag: 14.86070983099443
# Currently observing: SN2002dl
# 	Interpolated mag: 16.157346938775643
# 	Peak mag: 15.913
# 	Lumdist: 57.0
# 	Expected mag: 14.451291584485045
# Currently observing: SN2002es
# 	Interpolated mag: 18.578061435739357
# 	Peak mag: 17.307000000000002
# 	Lumdist: 75.0
# 	Expected mag: 16.07863007058328
# Currently observing: SN2002es
# 	Interpolated mag: 17.241999999999795
# 	Peak mag: 16.752
# 	Lumdist: 75.0
# 	Expected mag: 14.447316316958105
# Currently observing: SN2002es
# 	Interpolated mag: 16.66317258883262
# 	Peak mag: 16.211
# 	Lumdist: 75.0
# 	Expected mag: 15.270844022542398
# Currently observing: SN2002he
# 	Interpolated mag: 17.500473684210263
# 	Peak mag: 16.383
# 	Lumdist: 109.0
# 	Expected mag: 16.47607648970241
# Currently observing: SN2002he
# 	Interpolated mag: 16.91484210526305
# 	Peak mag: 15.8
# 	Lumdist: 109.0
# 	Expected mag: 16.476959752860804
# Currently observing: SN2002he
# 	Interpolated mag: 17.20478947368425
# 	Peak mag: 16.466
# 	Lumdist: 109.0
# 	Expected mag: 17.292537845641803
# Currently observing: SN2005hk
# 	Interpolated mag: 17.201118888451827
# 	Peak mag: 15.917
# 	Lumdist: 54.0
# 	Expected mag: 15.40052156015787
# Currently observing: SN2005hk
# 	Interpolated mag: 16.571162786484276
# 	Peak mag: 15.681
# 	Lumdist: 54.0
# 	Expected mag: 14.513896069972695
# Currently observing: SN2005ke
# 	Interpolated mag: 16.62983394497869
# 	Peak mag: 14.888
# 	Lumdist: 27.0
# 	Expected mag: 15.130286804347435
# Currently observing: SN2005ke
# 	Interpolated mag: 15.376527870488623
# 	Peak mag: 14.142000000000001
# 	Lumdist: 27.0
# 	Expected mag: 13.679913640377258
# Currently observing: SN2006H
# 	Interpolated mag: 20.206801831718504
# 	Peak mag: 18.031
# 	Lumdist: 62.577
# 	Expected mag: 18.126387036101228
# Currently observing: SN2006H
# 	Interpolated mag: 18.352431247845
# 	Peak mag: 17.04
# 	Lumdist: 62.577
# 	Expected mag: 15.65700219617461
# Currently observing: SN2006X
# 	Interpolated mag: 16.519091084857163
# 	Peak mag: 15.335999999999999
# 	Lumdist: 16.0
# 	Expected mag: 12.486579660224255
# Currently observing: SN2006X
# 	Interpolated mag: 14.899791084955833
# 	Peak mag: 13.974
# 	Lumdist: 16.0
# 	Expected mag: 11.941966737858543
# Currently observing: SN2006bq
# 	Interpolated mag: 18.093334431382686
# 	Peak mag: 16.531
# 	Lumdist: 100.0
# 	Expected mag: 17.48917829587049
# Currently observing: SN2006bq
# 	Interpolated mag: 17.059423679704185
# 	Peak mag: 16.288
# 	Lumdist: 100.0
# 	Expected mag: 15.620504751743457
# Currently observing: SN2006br
# 	Interpolated mag: 20.532750888668083
# 	Peak mag: 19.25
# 	Lumdist: 98.0
# 	Expected mag: 16.690992276088963
# Currently observing: SN2006br
# 	Interpolated mag: 19.00402563331017
# 	Peak mag: 18.227
# 	Lumdist: 98.0
# 	Expected mag: 15.587553337783998
# Currently observing: SN2006cp
# 	Interpolated mag: 16.89710702341112
# 	Peak mag: 16.029
# 	Lumdist: 90.0
# 	Expected mag: 15.387365296359828
# Currently observing: SN2006em
# 	Interpolated mag: 19.822738916256046
# 	Peak mag: 18.513
# 	Lumdist: 100.0
# 	Expected mag: 16.80767559605881
# Currently observing: SN2006em
# 	Interpolated mag: 18.90894726433759
# 	Peak mag: 17.505
# 	Lumdist: 100.0
# 	Expected mag: 16.85329321819397
# Currently observing: SN2006hb
# 	Interpolated mag: 17.63104035239381
# 	Peak mag: 15.909
# 	Lumdist: 63.0
# 	Expected mag: 16.916767618026412
# Currently observing: SN2006hb
# 	Interpolated mag: 16.59234976366091
# 	Peak mag: 15.556
# 	Lumdist: 63.0
# 	Expected mag: 15.133548436643025
# Currently observing: SN2006ot
# 	Interpolated mag: 19.008301335473025
# 	Peak mag: 18.116
# 	Lumdist: 239.893
# 	Expected mag: 17.581516881008596
# Currently observing: SN2006ot
# 	Interpolated mag: 18.668107039235434
# 	Peak mag: 17.884
# 	Lumdist: 97.07600000000001
# 	Expected mag: 15.533613141879684
# Currently observing: SN2009dc
# 	Interpolated mag: 15.500802313964979
# 	Peak mag: 15.2184
# 	Lumdist: 97.07600000000001
# 	Expected mag: 14.602961474910824
# Currently observing: SN2009dc
# 	Interpolated mag: 15.581197969543187
# 	Peak mag: 15.2651
# 	Lumdist: 97.07600000000001
# 	Expected mag: 15.684680780221552
# Currently observing: SN2009ig
# 	Interpolated mag: 14.24674042442142
# 	Peak mag: 13.548
# 	Lumdist: 33.0
# 	Expected mag: 12.751771364478426
# Currently observing: SN2009ig
# 	Interpolated mag: 14.01881146685992
# 	Peak mag: 13.422
# 	Lumdist: 33.0
# 	Expected mag: 12.872755248299423
# Currently observing: SN2010ae
# 	Interpolated mag: 18.54697919687953
# 	Peak mag: 17.953
# 	Lumdist: 9.0
# 	Expected mag: 9.647768420377599
# Currently observing: SN2010ae
# 	Interpolated mag: 17.72761892950382
# 	Peak mag: 17.104
# 	Lumdist: 9.0
# 	Expected mag: 10.103645840799572
# Currently observing: SN2011ay
# 	Interpolated mag: 18.423270284211146
# 	Peak mag: 17.04
# 	Lumdist: 94.4
# 	Expected mag: 16.88092319829202
# Currently observing: SN2011ay
# 	Interpolated mag: 17.14759717201786
# 	Peak mag: 16.7
# 	Lumdist: 94.4
# 	Expected mag: 14.864226859753156
# Currently observing: SN2012Z
# 	Interpolated mag: 16.379665880873656
# 	Peak mag: 14.73
# 	Lumdist: 31.705
# 	Expected mag: 15.23043733421203
# Currently observing: SN2012Z
# 	Interpolated mag: 15.198359223300988
# 	Peak mag: 14.412
# 	Lumdist: 31.705
# 	Expected mag: 13.15525291382853
# Currently observing: SN2012dn
# 	Interpolated mag: 15.10122222222246
# 	Peak mag: 14.341
# 	Lumdist: 45.4355
# 	Expected mag: 13.612056113839387
# Currently observing: SN2012dn
# 	Interpolated mag: 14.65199999999978
# 	Peak mag: 14.200999999999999
# 	Lumdist: 45.4355
# 	Expected mag: 13.28297555828276
# Currently observing: SN2012dn
# 	Interpolated mag: 14.348454545454567
# 	Peak mag: 14.181
# 	Lumdist: 45.4355
# 	Expected mag: 13.8761576491923
# Currently observing: SN2013dh
# 	Interpolated mag: 18.5029164223602
# 	Peak mag: 17.504
# 	Lumdist: 59.7123
# 	Expected mag: 14.849395505881095
# Currently observing: SN2013dh
# 	Interpolated mag: 17.641285795132962
# 	Peak mag: 17.46
# 	Lumdist: 59.7123
# 	Expected mag: 13.350645013067417
# Currently observing: SN2013hh
# 	Interpolated mag: 18.49292931457684
# 	Peak mag: 17.372
# 	Lumdist: 53.6
# 	Expected mag: 14.944091239192169
# Currently observing: SN2014J
# 	Interpolated mag: 12.712965763689256
# 	Peak mag: 11.845999999999998
# 	Lumdist: 2.998
# 	Expected mag: 7.9972317729949225
# Currently observing: SN2014J
# 	Interpolated mag: 11.237320737741719
# 	Peak mag: 10.56
# 	Lumdist: 2.998
# 	Expected mag: 7.821256260419915
# Currently observing: SN2014J
# 	Interpolated mag: 10.380620030196285
# 	Peak mag: 9.697000000000001
# 	Lumdist: 2.998
# 	Expected mag: 8.528733295052504
# Currently observing: SN2014ek
# 	Interpolated mag: 19.317024793388544
# 	Peak mag: 17.654
# 	Lumdist: 104.0
# 	Expected mag: 17.846007589056192
# Currently observing: SN2014ek
# 	Interpolated mag: 18.257234042553275
# 	Peak mag: 16.909000000000002
# 	Lumdist: 104.0
# 	Expected mag: 16.82987484543023
# Currently observing: SN2014ek
# 	Interpolated mag: 17.626528925619844
# 	Peak mag: 17.0
# 	Lumdist: 104.0
# 	Expected mag: 16.16831182046085
# Currently observing: SN2016ajf
# 	Interpolated mag: 17.365772529069513
# 	Peak mag: 16.08
# 	Lumdist: 91.23
# 	Expected mag: 16.42365903347546
# Currently observing: SN2016bfu
# 	Interpolated mag: 17.941733472396606
# 	Peak mag: 16.211
# 	Lumdist: 46.4109
# 	Expected mag: 16.276618860214374
# Currently observing: SN2016bfu
# 	Interpolated mag: 16.71474080921563
# 	Peak mag: 15.535
# 	Lumdist: 46.4109
# 	Expected mag: 14.749414788849592
# Currently observing: SN2016bln
# 	Interpolated mag: 16.74194699967333
# 	Peak mag: 15.81758294
# 	Lumdist: 104.851
# 	Expected mag: 15.870797117182427
# Currently observing: SN2016bln
# 	Interpolated mag: 16.65538809464497
# 	Peak mag: 15.915394400000002
# 	Lumdist: 104.851
# 	Expected mag: 15.662110595046823
# Currently observing: SN2016ccj
# 	Interpolated mag: 17.492502125810663
# 	Peak mag: 16.955
# 	Lumdist: 190.8
# 	Expected mag: 16.567483495045366
# Currently observing: SN2016ija
# 	Interpolated mag: 18.884279835392526
# 	Peak mag: 17.535
# 	Lumdist: 15.389000000000001
# 	Expected mag: 12.682798397430297
# Currently observing: SN2017dzs
# 	Interpolated mag: 17.764914144613492
# 	Peak mag: 16.6959
# 	Lumdist: 77.4339
# 	Expected mag: 15.645164234298846
# Currently observing: SN2017fzw
# 	Interpolated mag: 15.989640487190501
# 	Peak mag: 14.18
# 	Lumdist: 24.0
# 	Expected mag: 15.057466242998004
# Currently observing: SN2017fzw
# 	Interpolated mag: 14.632036486882118
# 	Peak mag: 13.668
# 	Lumdist: 24.0
# 	Expected mag: 12.896963321491281
# Currently observing: SN2017htb
# 	Interpolated mag: 17.6270463922711
# 	Peak mag: 16.7737
# 	Lumdist: 121.265
# 	Expected mag: 15.995005921865669
# Currently observing: SN2017htb
# 	Interpolated mag: 16.950744661366574
# 	Peak mag: 16.3059
# 	Lumdist: 121.265
# 	Expected mag: 15.792479600521695
# --------------------------------------------------------
# Total SNe that satisfy light curve requirements for B-band: 50
# Percentage of SNe that satisfyB-band error on expected peak mag: 0.68
# --------------------------------------------------------
# Total SNe that satisfy light curve requirements for V-band: 54
# Percentage of SNe that satisfyV-band error on expected peak mag: 0.2777777777777778
# --------------------------------------------------------
# Total SNe that satisfy light curve requirements for I-band: 31
# Percentage of SNe that satisfyI-band error on expected peak mag: 0.3548387096774194
